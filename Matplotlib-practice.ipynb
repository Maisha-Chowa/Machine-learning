# %%
# Resource: https://www.datacamp.com/tutorial/matplotlib-tutorial-python

import pandas as pd

djia_data = pd.read_csv('HistoricalPrices.csv')
djia_data.head()
# Out:
#        Date      Open      High       Low     Close
# 0  04/17/26  48788.81  49717.98  48788.81  49447.43
# 1  04/16/26  48557.82  48683.45  48337.38  48578.72
# 2  04/15/26  48549.14  48709.01  48281.62  48463.72
# 3  04/14/26  48272.03  48592.29  48192.30  48535.99
# 4  04/13/26  47718.21  48221.37  47505.97  48218.25

# %%
djia_data = djia_data.rename(columns = {' Open': 'Open', ' High': 'High', ' Low': 'Low', ' Close': 'Close'})

# %%
djia_data['Date'] = pd.to_datetime(djia_data['Date'])
djia_data = djia_data.sort_values(by = 'Date')
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_14212\220103799.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   djia_data['Date'] = pd.to_datetime(djia_data['Date'])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.dates as mdates

# %%
plt.plot(djia_data['Date'], djia_data['Open'], label="Open")
plt.plot(djia_data['Date'], djia_data['Close'], label="Close")

ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter("%m/%Y"))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))

plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
